# %%
import requests
import time
import os
from pathlib import Path
from random import randint
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import datetime
from datetime import date
str(date.today())
# Out:
# '2020-02-11'

# %%
WRITE_DIR=Path('news')

# %%
'''
function to sleep for a random amount of time between min_sleep and max_sleep
'''
def random_sleep(min_sleep=1, max_sleep=10, verbose=False):
    sleep_time = randint(min_sleep, max_sleep)
    if verbose:
        print('sleep', str(sleep_time))
    time.sleep(sleep_time)

# %%
def parse_date(date_str):
    return_date = date_str.replace('T',' ').replace('Z','')
    return_date = datetime.datetime.strptime(return_date,'%Y-%m-%d %H:%M:%S').date()
    return return_date

# %%
'''
function to extract list of news items from the json content
'''
def extract_news(content):
    news_items = []
    for item in content['wireitems']:
        if item['wireitem_type'] != 'story':
            continue
        news={'id': item['wireitem_id'],
              'headline': item['templates'][0]['story']['hed'],
              'lede': item['templates'][0]['story']['lede'],
              'date': item['templates'][0]['story']['updated_at'],
              'url': item['templates'][0]['template_action']['url']}
        if 'image' in item['templates'][0]:
            news['img_cap'] = item['templates'][0]['image']['caption']
            news['img_url'] = item['templates'][0]['image']['url']
        news_items.append(news)
    return news_items

# %%
'''
function to fetch news items for a given stock symbol with different start and stop criteria

parameters:
stop_count -> min num of news articles to fetch
stop_date -> date in past that should be included in the fetched news items
last_id -> start fetching from the intermediate id
'''
def fetch_news(symbol,stop_count=100000, stop_date=date(2019,1,1), last_id=None, verbose=False):
    if verbose:
        print(f'\nfetch news for {symbol}, stop_count:{stop_count}, stop_date:{stop_date}')
    URL=f'https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:{symbol}'
    retry=0
    news_items=[]
    errors = []
    last_date = date.today()
    while len(news_items) < stop_count and stop_date <= last_date:
        params = {'until':last_id} if last_id else {}
        while retry < 3:
            try:
                retry = retry + 1
                random_sleep(verbose=verbose)
                if verbose:
                    print('Fetching URL:', URL, 'params:', params)
                response = requests.get(URL, params=params)
                if response:
                    retry = 0
                    break
            except Exception as e:
                print(f'Exception thrown in fetch_news for {symbol}',e)
                errors.append(e)
                pass
        items = extract_news(response.json())
        news_items.extend(items)
        last_id = news_items[-1]['id']
        last_date = parse_date(news_items[-1]['date'])
        if verbose:
            print(f'Collected {len(news_items)} news items for {symbol} with {len(errors)} errors' )
    if verbose:
        print(f'last_id: {last_id}, last_date: {str(last_date)}')
    return news_items

# %%
'''
function to fetch news items for a list of stock symbols and store results in local directory as json file

parameters:
stop_count -> min num of news articles to fetch
stop_date -> date in past that should be included in the fetched news items
last_id -> start fetching from the intermediate id
write_dir -> directory to write results in json format
'''
def scrape_news(symbols,stop_count=100000, stop_date=date(2019,1,1),write_dir=WRITE_DIR,verbose=False):
    for symbol in symbols:
        sym_stop_date = stop_date[symbol] if type(stop_date) == dict and symbol in stop_date else stop_date
        news_items = fetch_news(symbol,stop_count=stop_count,stop_date=sym_stop_date,verbose=verbose)
        data_dict = {'ticker':symbol, 
                     'news_items':news_items}
        filename=symbol.split('.')[0]
        file_path_str = write_dir / (filename +'.json')
        with open(file_path_str, "w") as write_file:
            print(f'Writing file for {symbol}')
            json.dump(data_dict, write_file)

# %%
def find_stop_date(data,symbol):
    symbol = symbol.split('.')[0]
    dates = data.loc[data['ticker'] == symbol, 'created_at']
    return dates.min()

# %%
all_data = pd.read_pickle('stocktwits_labelled.pkl')
print(all_data.shape)
print(all_data.columns)
all_data['created_at'] = all_data['created_at'].apply(parse_date)
# Out:
# (137996, 35)
# Index(['id', 'body', 'created_at', 'user', 'source', 'symbols',
#        'mentioned_users', 'entities', 'filters', 'conversation', 'likes',
#        'links', 'reshare_message', 'reshares', 'structurable', 'ticker',
#        'user_followers', 'user_following', 'user_join_date', 'user_ideas',
#        'user_identity', 'user_like_count', 'user_official',
#        'user_wtchlst_count', 'username', 'sentiment', 'num_likes',
#        'num_reshares', 'num_replies', 'day_counts', 'raw_body', 'char_length',
#        'bearish_score', 'bullish_score', 'sentiment_pred'],
#       dtype='object')

# %%
symbols=['AAPL.O','TWTR.N','FB.O','TSLA.O', 'SPY.N', 'DIA.N','GOOGL.O', 'MSFT.O','AMZN.O', 'AMD.O', 'INTC.O','BABA.N']
stop_date = date(2019,11,25)
stop_date = {s:find_stop_date(all_data,s) for s in symbols} # extract stop_date for each symbol
scrape_news(symbols,stop_date=stop_date,write_dir=WRITE_DIR,verbose=True)
# Out:
# fetch news for AAPL.O, stop_count:100000, stop_date:2020-01-11
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AAPL.O params: {}
# Collected 20 news items for AAPL.O with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AAPL.O params: {'until': '1580425516023208000'}
# Collected 39 news items for AAPL.O with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AAPL.O params: {'until': '1580213040039227000'}
# Collected 58 news items for AAPL.O with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AAPL.O params: {'until': '1579179543044276000'}
# Collected 77 news items for AAPL.O with 0 errors
# last_id: 1576261313014149000, last_date: 2019-12-13
# Writing file for AAPL.O
#
# fetch news for TWTR.N, stop_count:100000, stop_date:2019-10-29
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:TWTR.N params: {}
# Collected 20 news items for TWTR.N with 0 errors
# last_id: 1571964528063777000, last_date: 2019-10-25
# Writing file for TWTR.N
#
# fetch news for FB.O, stop_count:100000, stop_date:2019-12-04
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:FB.O params: {}
# Collected 20 news items for FB.O with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:FB.O params: {'until': '1579877105023892000'}
# Collected 39 news items for FB.O with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:FB.O params: {'until': '1577738903002256000'}
# Collected 58 news items for FB.O with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:FB.O params: {'until': '1576204061000161000'}
# Collected 77 news items for FB.O with 0 errors
# last_id: 1573746722007433000, last_date: 2019-11-14
# Writing file for FB.O
#
# fetch news for TSLA.O, stop_count:100000, stop_date:2020-01-21
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:TSLA.O params: {}
# Collected 20 news items for TSLA.O with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:TSLA.O params: {'until': '1580434978044276000'}
# Collected 39 news items for TSLA.O with 0 errors
# last_id: 1579453022004645000, last_date: 2020-01-19
# Writing file for TSLA.O
#
# fetch news for SPY.N, stop_count:100000, stop_date:2020-01-21
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {}
# Collected 20 news items for SPY.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1581341443064976000'}
# Collected 39 news items for SPY.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1581252508064976000'}
# Collected 58 news items for SPY.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1581153936053501000'}
# Collected 77 news items for SPY.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1581067307060261000'}
# Collected 96 news items for SPY.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580965987057608000'}
# Collected 115 news items for SPY.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580862891064976000'}
# Collected 134 news items for SPY.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580749805026091000'}
# Collected 153 news items for SPY.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580658952065401000'}
# Collected 172 news items for SPY.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580542238040139000'}
# Collected 191 news items for SPY.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580471899004780000'}
# Collected 210 news items for SPY.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580385975002273000'}
# Collected 229 news items for SPY.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580290380031231000'}
# Collected 248 news items for SPY.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580220796031231000'}
# Collected 267 news items for SPY.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580131345053501000'}
# Collected 286 news items for SPY.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1580043600064976000'}
# Collected 305 news items for SPY.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1579867400037199000'}
# Collected 324 news items for SPY.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1579765500065401000'}
# Collected 343 news items for SPY.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:SPY.N params: {'until': '1579631866031231000'}
# Collected 362 news items for SPY.N with 0 errors
# last_id: 1579558627064976000, last_date: 2020-01-20
# Writing file for SPY.N
#
# fetch news for DIA.N, stop_count:100000, stop_date:2019-08-14
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {}
# Collected 20 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1581330802002273000'}
# Collected 39 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1581163555064976000'}
# Collected 58 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1581071585060261000'}
# Collected 77 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580962600009716000'}
# Collected 96 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580751867037199000'}
# Collected 115 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580574476060261000'}
# Collected 134 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580475647004780000'}
# Collected 153 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580324870004780000'}
# Collected 172 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580221805026091000'}
# Collected 191 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1580063875053501000'}
# Collected 210 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1579785111064976000'}
# Collected 229 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1579619700053501000'}
# Collected 248 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1579429767064976000'}
# Collected 267 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1579254595004780000'}
# Collected 286 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1579095097053501000'}
# Collected 305 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578947787058494000'}
# Collected 324 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578816028032484000'}
# Collected 343 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578675488044050000'}
# Collected 362 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578568905031231000'}
# Collected 381 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578406180026091000'}
# Collected 400 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578311820037199000'}
# Collected 419 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1578071953060261000'}
# Collected 438 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1577970000004780000'}
# Collected 457 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1577731895064976000'}
# Collected 476 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1577613738064976000'}
# Collected 495 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1577353260020369000'}
# Collected 514 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1577094689032484000'}
# Collected 533 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1576847980002273000'}
# Collected 552 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1576761078057608000'}
# Collected 571 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1576580307004780000'}
# Collected 590 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1576488606060261000'}
# Collected 609 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1576224686004780000'}
# Collected 628 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575990729037199000'}
# Collected 647 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575894775058494000'}
# Collected 666 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575721739058494000'}
# Collected 685 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575553499026091000'}
# Collected 704 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575381236062501000'}
# Collected 723 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1575290626060261000'}
# Collected 742 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574952007057608000'}
# Collected 761 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574767424060261000'}
# Collected 780 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574591764064976000'}
# Collected 799 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574411724002273000'}
# Collected 818 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574229763037199000'}
# Collected 837 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1574090267058494000'}
# Collected 856 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573929663058494000'}
# Collected 875 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573802822065401000'}
# Collected 894 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573653804032484000'}
# Collected 913 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573495337004780000'}
# Collected 932 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573322633060261000'}
# Collected 951 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573153480037199000'}
# Collected 970 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1573064885062501000'}
# Collected 989 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572959140009716000'}
# Collected 1008 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572865200057608000'}
# Collected 1027 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572778837064976000'}
# Collected 1046 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572612229057608000'}
# Collected 1065 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572501264053501000'}
# Collected 1084 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572352089053501000'}
# Collected 1103 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572242904009716000'}
# Collected 1122 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1572072863009716000'}
# Collected 1141 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571896813064976000'}
# Collected 1160 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571731616053501000'}
# Collected 1179 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571565483032484000'}
# Collected 1198 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571387062004780000'}
# Collected 1217 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571221440058494000'}
# Collected 1236 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1571107701037199000'}
# Collected 1255 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570963092065401000'}
# Collected 1274 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570724358044050000'}
# Collected 1293 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570640495053501000'}
# Collected 1312 news items for DIA.N with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570454326026091000'}
# Collected 1331 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570272600031231000'}
# Collected 1350 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570174377032484000'}
# Collected 1369 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570100700031231000'}
# Collected 1388 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1570012661057608000'}
# Collected 1407 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569899893031231000'}
# Collected 1426 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569700309032484000'}
# Collected 1445 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569562494020369000'}
# Collected 1464 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569466167020369000'}
# Collected 1483 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569337803002273000'}
# Collected 1502 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569256116002273000'}
# Collected 1521 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1569127122004780000'}
# Collected 1540 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568898138057608000'}
# Collected 1559 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568660499064976000'}
# Collected 1578 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568548800062501000'}
# Collected 1597 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568381413031231000'}
# Collected 1616 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568266963026091000'}
# Collected 1635 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1568148699065401000'}
# Collected 1654 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567965626009716000'}
# Collected 1673 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567800233062501000'}
# Collected 1692 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567701254032484000'}
# Collected 1711 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567657163009716000'}
# Collected 1730 news items for DIA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567555555058494000'}
# Collected 1749 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567465783037199000'}
# Collected 1768 news items for DIA.N with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567249560031231000'}
# Collected 1787 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1567120003026091000'}
# Collected 1806 news items for DIA.N with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566984957044050000'}
# Collected 1825 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566800280020369000'}
# Collected 1844 news items for DIA.N with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566726814053501000'}
# Collected 1863 news items for DIA.N with 0 errors
# sleep 10
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566561712062501000'}
# Collected 1882 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566510309002273000'}
# Collected 1901 news items for DIA.N with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566315975032484000'}
# Collected 1920 news items for DIA.N with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566222156004780000'}
# Collected 1939 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1566043140065401000'}
# Collected 1958 news items for DIA.N with 0 errors
# sleep 5
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1565938040065401000'}
# Collected 1977 news items for DIA.N with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:DIA.N params: {'until': '1565789590064976000'}
# Collected 1996 news items for DIA.N with 0 errors
# last_id: 1565634375020369000, last_date: 2019-08-12
# Writing file for DIA.N
#
# fetch news for GOOGL.O, stop_count:100000, stop_date:2019-07-25
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:GOOGL.O params: {}
# Collected 20 news items for GOOGL.O with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:GOOGL.O params: {'until': '1575930438014149000'}
# Collected 39 news items for GOOGL.O with 0 errors
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:GOOGL.O params: {'until': '1573091230002256000'}
# Collected 58 news items for GOOGL.O with 0 errors
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:GOOGL.O params: {'until': '1568278362039227000'}
# Collected 77 news items for GOOGL.O with 0 errors
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:GOOGL.O params: {'until': '1564352936015257000'}
# Collected 96 news items for GOOGL.O with 0 errors
# last_id: 1559615493054695000, last_date: 2019-06-04
# Writing file for GOOGL.O
#
# fetch news for MSFT.O, stop_count:100000, stop_date:2019-11-15
# sleep 6
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:MSFT.O params: {}
# Collected 20 news items for MSFT.O with 0 errors
# sleep 9
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:MSFT.O params: {'until': '1574213951017402000'}
# Collected 39 news items for MSFT.O with 0 errors
# last_id: 1572285392011806000, last_date: 2019-10-28
# Writing file for MSFT.O
#
# fetch news for AMZN.O, stop_count:100000, stop_date:2020-01-06
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AMZN.O params: {}
# Collected 20 news items for AMZN.O with 0 errors
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AMZN.O params: {'until': '1579813439044787000'}
# Collected 39 news items for AMZN.O with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AMZN.O params: {'until': '1578882877057853000'}
# Collected 58 news items for AMZN.O with 0 errors
# last_id: 1576693444007726000, last_date: 2019-12-18
# Writing file for AMZN.O
#
# fetch news for AMD.O, stop_count:100000, stop_date:2020-01-09
# sleep 2
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:AMD.O params: {}
# Collected 20 news items for AMD.O with 0 errors
# last_id: 1548797131029335000, last_date: 2019-01-29
# Writing file for AMD.O
#
# fetch news for INTC.O, stop_count:100000, stop_date:2019-07-12
# sleep 7
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:INTC.O params: {}
# Collected 20 news items for INTC.O with 0 errors
# sleep 4
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:INTC.O params: {'until': '1575295161007726000'}
# Collected 39 news items for INTC.O with 0 errors
# sleep 8
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:INTC.O params: {'until': '1568188743044276000'}
# Collected 58 news items for INTC.O with 0 errors
# last_id: 1557344409061807000, last_date: 2019-05-08
# Writing file for INTC.O
#
# fetch news for BABA.N, stop_count:100000, stop_date:2019-12-03
# sleep 3
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:BABA.N params: {}
# Collected 20 news items for BABA.N with 0 errors
# sleep 1
# Fetching URL: https://wireapi.reuters.com/v8/feed/rcom/us/marketnews/ric:BABA.N params: {'until': '1575572660040139000'}
# Collected 39 news items for BABA.N with 0 errors
# last_id: 1573652453023892000, last_date: 2019-11-13
# Writing file for BABA.N

# %%
NEWS_DIR=Path('news')
df_list = []
for file in os.listdir(NEWS_DIR):
    with open(NEWS_DIR / file, "r") as read_file:
        data = json.load(read_file)
    df = pd.DataFrame(data['news_items'])
    df['ticker'] = data['ticker'].split('.')[0]
    df_list.append(df)
    
news = pd.concat(df_list, ignore_index=True,sort=False)
news['date'] = news['date'].apply(parse_date)

# %%
news.to_pickle('reuters.pkl')
news = pd.read_pickle('reuters.pkl')
news.shape
# Out:
# (2881, 8)
